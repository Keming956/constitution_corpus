# %%
#Ce script permet de diviser le corpus en 3 parties : train, dev et test

# %%
import json
import random
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Step 1: Load the data
with open("../data/clean/corpus_traité.json", "r", encoding="utf-8") as file:
    data = [json.loads(line) for line in file]

# Step 2: Split the data
train_data, temp_data = train_test_split(data, test_size=0.2, random_state=42)
dev_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# Step 3: Visualize the split
labels = ["Train", "Dev", "Test"]
sizes = [len(train_data), len(dev_data), len(test_data)]

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=140)
plt.axis("equal")
plt.title("Dataset Split")
plt.show()

# %%
# Saving the datasets to JSON files
with open("../data/clean/train_data.json", "w", encoding="utf-8") as file:
    json.dump(train_data, file, ensure_ascii=False, indent=4)

with open("../data/clean/dev_data.json", "w", encoding="utf-8") as file:
    json.dump(dev_data, file, ensure_ascii=False, indent=4)

with open("../data/clean/test_data.json", "w", encoding="utf-8") as file:
    json.dump(test_data, file, ensure_ascii=False, indent=4)
